# %%
from functions.get_function_setting import get_function_setting
from algorithms import genetic_algorithm
from matplotlib import pyplot as plt
from numpy import mean, median, std, array, VisibleDeprecationWarning
import pandas as pd
import warnings
warnings.filterwarnings("ignore", category=VisibleDeprecationWarning)

# %%
def main(
    number_iteration: int = 500,
    number_bit: int = 16,
    number_population: int = 50,
    cross_rate: float = 0.9
):
    data_table = pd.DataFrame([[None, None, None, None] for _ in range(7)], columns=[
        "Average Fitness",
        "Median Fitness",
        "Average Solution",
        "Standard Deviation of Solution"
    ])

    data_table.index = ["function " + str(index+1) for index in range(7)]

    for function_number in range(1, 7+1, 1):
        best_fitnesses = []
        solutions = []
        best_fitness_sets = []
        for _ in range(50):
            function_setting = get_function_setting(function_number)
            mutation_rate = 1 / (number_bit * function_setting["dimension"])
            boundaries = [function_setting["boundary"]] * function_setting["dimension"]

            best_solution, best_fitness, best_fitness_set = \
                genetic_algorithm(
                    function_setting["function"],
                    boundaries,
                    number_bit,
                    number_iteration,
                    number_population,
                    cross_rate,
                    mutation_rate
                )

            solutions.append(best_solution)
            best_fitnesses.append(best_fitness)
            best_fitness_sets.append(best_fitness_set)

        plt.plot(mean(best_fitness_sets, axis=0))
        plt.show()

        solutions = array(solutions).reshape((-1, function_setting["dimension"]))
        
        data_table.iloc[function_number-1] = [mean(best_fitnesses), median(best_fitnesses), mean(solutions, axis=0), std(solutions ,axis=0)]
        # print("-" * 20)
        # print(f"Average Fitness: {data_table.iloc[function_number-1, 0]}")
        # print(f"Median Fitness: {data_table.iloc[function_number-1, 1]}")
        # print(f"Average solution: {data_table.iloc[function_number-1, 2]}")
        # print(f"Standard Deviation of solution: {data_table.iloc[function_number-1, 3]}")

    data_table.to_csv(f"./data/GA_iteration_{number_iteration}.csv")

# %%
main(
    number_iteration=500,
    number_bit=16,
    number_population=50,
    cross_rate=0.9
)

# %%
main(
    number_iteration=2500,
    number_bit=16,
    number_population=50,
    cross_rate=0.9
)
